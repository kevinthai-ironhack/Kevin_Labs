# %% [markdown]
# ### Tasks
# Part 1: Upload the data
#
# Part 2: Analyze your data and create a plan for data preparation
#
# Part 3: Data cleansing (missing values, outliers, duplicates, data consistently)
#
# Part 4: Encode categorical data
#
# Part 5: Upload the deliverables to GitHub

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('data_cleaning.csv',low_memory=False)

# %% [markdown]
# ### Data Inspection

# %%
df.shape
# Out:
# (30, 7)

# %%
# conclusion: some null data, birthyear type is float (weird)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionID  30 non-null     int64
#  1   ClientID       30 non-null     int64
#  2   BirthYear      28 non-null     float64
#  3   Amount         30 non-null     int64
#  4   Profession     28 non-null     object
#  5   Department     30 non-null     int64
#  6   Risk           30 non-null     object
# dtypes: float64(1), int64(4), object(2)
# memory usage: 1.8+ KB

# %%
df.head(10)
#we can observe case sensitivity
# Out:
#    TransactionID  ClientID  BirthYear   Amount  Profession  Department    Risk
# 0              4     34985     1923.0     5670     manager          78     Low
# 1             16     34997     1923.0  2399090   developer          78    High
# 2             25     35006     1923.0    33050          HR          78    High
# 3             12     34993     1939.0    23430   professor          78     Low
# 4             21     35002     1939.0    16770     manager          78     Low
# 5             11     34992     1944.0    21210  researcher          78  Medium
# 6             20     35001     1944.0    14550     student          78  Medium
# 7              3     34984     1945.0     3450     student          78  Medium
# 8             19     35000     1949.0    12330      barmen          78    High
# 9              9     34990     1953.0    16770     Manager          78  Medium

# %%
# show unique values of a column
# Need harmonization within the labels:
# 'manager', 'Manager'
# 'student','edudient','Student'
# 'bdm','BDM'
df["Profession"].unique()
# Out:
# array(['manager', 'developer', 'HR', 'professor', 'researcher', 'student',
#        'barmen', 'Manager', 'bdm', nan, 'hr', 'etudient', 'BDM',
#        'Hairdresser', 'Student', 'Driver', 'sailer'], dtype=object)

# %% [markdown]
# ### CLEANING ACTION PLAN
#
# 1. Deal with NaN values
# 2. Formatting BirthYear type into integer
# 3. Clean Profession labels
# 4. Check consistency & duplicates
# 5. Remove outliers

# %% [markdown]
# ### General Formatting

# %%
#lowering string to lowercase to deal with BDM bdm etc.
df['Profession'] = df['Profession'].astype('str')
df['Risk'] = df['Risk'].astype('str')
df['Profession'] = df['Profession'].str.lower()
df['Risk'] = df['Risk'].str.lower()

# %%
df["Profession"].unique()
# Out:
# array(['manager', 'developer', 'hr', 'professor', 'researcher', 'student',
#        'barmen', 'bdm', 'nan', 'etudient', 'hairdresser', 'driver',
#        'sailer'], dtype=object)

# %%
df['Profession'] = df['Profession'].replace('etudient','student')

# %%
df["Profession"].unique()
# Out:
# array(['manager', 'developer', 'hr', 'professor', 'researcher', 'student',
#        'barmen', 'bdm', 'nan', 'hairdresser', 'driver', 'sailer'],
#       dtype=object)

# %% [markdown]
# ### Dealing with Nan values

# %%
# Deal with NaN values
null_displ = df[(df['BirthYear'].isnull()==True) | (df['Profession']=='nan')]
null_displ
# Out:
#     TransactionID  ClientID  BirthYear  Amount Profession  Department    Risk
# 15             28     35008     1967.0   46370        nan          78    high
# 16             29     35008     1976.0   50810        nan          78  medium
# 28             22     34987        NaN   18990     sailer          78    high
# 29              7     34988        NaN   12330    manager          78  medium

# %%
# Let's replace NaN year value by 0 and NaN profession value by unknown
df['BirthYear'].fillna(0,inplace=True)

# %%
df['BirthYear'] = df['BirthYear'].astype('int')
df['BirthYear'].dtype
# Out:
# dtype('int32')

# %%
pivot = df.groupby('ClientID').agg({'TransactionID':'count'}).sort_values(by='TransactionID',ascending=False)
pivot.head(6)
# Out:
#           TransactionID
# ClientID
# 35008                 3
# 34987                 3
# 34988                 2
# 34989                 2
# 34991                 2
# 34997                 1

# %%
sus_clients = pivot.head(5).index

# %%
df.loc[df['ClientID'].isin(sus_clients)].sort_values(by="ClientID",ascending=False)
# Out:
#     TransactionID  ClientID  BirthYear  Amount Profession  Department    Risk
# 14             27     35008       1967   41930        bdm          78     low
# 15             28     35008       1967   46370        nan          78    high
# 16             29     35008       1976   50810        nan          78  medium
# 19             10     34991       1988   18990        bdm          78     low
# 20             30     34991       1988   55250        bdm          78    high
# 10              8     34989       1958   14550         hr          78    high
# 13             24     34989       1967   27870         hr          78  medium
# 22             23     34988       1999   25650    manager          78     low
# 29              7     34988          0   12330    manager          78  medium
# 11              6     34987       1967   10110    manager          78  medium
# 12             15     34987       1967   30090    manager          78     low
# 28             22     34987          0   18990     sailer          78    high

# %%
# changing values for suspicious clients
# df.loc[index].at['column']

# %%
# CASE ID 34987, input birthyear and correctjob
df.at[28,'BirthYear'] = 1967
df.at[28,'Profession'] = 'manager'

# %%
# CASE ID 34988, input birthyear
df.at[29,'BirthYear'] = 1999

# %%
# CASE ID 34989, input birthyear taking 1958 BECAUSE first transaction precedence (assumption)
df.at[13,'BirthYear'] = 1958

# %%
# CASE ID 35008, input birthyear and correct job
df.at[16,'BirthYear'] = 1967
df.at[16,'Profession'] = 'bdm'
df.at[15,'Profession'] = 'bdm'

# %%
#checking
df.loc[df['ClientID'].isin(sus_clients)].sort_values(by="ClientID",ascending=False)
# Out:
#     TransactionID  ClientID  BirthYear  Amount Profession  Department    Risk
# 14             27     35008       1967   41930        bdm          78     low
# 15             28     35008       1967   46370        bdm          78    high
# 16             29     35008       1967   50810        bdm          78  medium
# 19             10     34991       1988   18990        bdm          78     low
# 20             30     34991       1988   55250        bdm          78    high
# 10              8     34989       1958   14550         hr          78    high
# 13             24     34989       1958   27870         hr          78  medium
# 22             23     34988       1999   25650    manager          78     low
# 29              7     34988       1999   12330    manager          78  medium
# 11              6     34987       1967   10110    manager          78  medium
# 12             15     34987       1967   30090    manager          78     low
# 28             22     34987       1967   18990    manager          78    high

# %%
#checking the rest 
df.loc[~df['ClientID'].isin(sus_clients)].sort_values(by="BirthYear",ascending=False)
# Out:
#     TransactionID  ClientID  BirthYear   Amount   Profession  Department  \
# 27             13     34994       2017    25650       driver          78
# 26              2     34983       2015     1230       barmen          78
# 25              1     34982       2013    12900      student          78
# 24             26     35007       1999    37490      student          78
# 23             14     34995       1999    27870  hairdresser          78
# 21             18     34999       1988    10110      student          78
# 17              5     34986       1978     7890           hr          78
# 18             17     34998       1978     7890      student          78
# 9               9     34990       1953    16770      manager          78
# 8              19     35000       1949    12330       barmen          78
# 7               3     34984       1945     3450      student          78
# 6              20     35001       1944    14550      student          78
# 5              11     34992       1944    21210   researcher          78
# 4              21     35002       1939    16770      manager          78
# 3              12     34993       1939    23430    professor          78
# 1              16     34997       1923  2399090    developer          78
# 2              25     35006       1923    33050           hr          78
# 0               4     34985       1923     5670      manager          78
#
#       Risk
# 27  medium
# 26    high
# 25     low
# 24  medium
# 23     low
# 21     low
# 17    high
# 18  medium
# 9   medium
# 8     high
# 7   medium
# 6   medium
# 5   medium
# 4      low
# 3      low
# 1     high
# 2     high
# 0      low

# %%
df[ (df['Profession'] != 'student') & (df['BirthYear'] > 2004) ]
# Out:
#     TransactionID  ClientID  BirthYear  Amount Profession  Department    Risk
# 26              2     34983       2015    1230     barmen          78    high
# 27             13     34994       2017   25650     driver          78  medium

# %%
# taking the mod
df['BirthYear'].value_counts()
# Out:
# 1967    6
# 1999    4
# 1923    3
# 1988    3
# 1939    2
# 1944    2
# 1958    2
# 1978    2
# 1945    1
# 1949    1
# 1953    1
# 2013    1
# 2015    1
# 2017    1
# Name: BirthYear, dtype: int64

# %%
# CHANGING YOUNG BABIES TO MODE
df.at[26,'BirthYear'] = 1967
df.at[27,'BirthYear'] = 1967

# %%
# quick check
df
# Out:
#     TransactionID  ClientID  BirthYear   Amount   Profession  Department  \
# 0               4     34985       1923     5670      manager          78
# 1              16     34997       1923  2399090    developer          78
# 2              25     35006       1923    33050           hr          78
# 3              12     34993       1939    23430    professor          78
# 4              21     35002       1939    16770      manager          78
# 5              11     34992       1944    21210   researcher          78
# 6              20     35001       1944    14550      student          78
# 7               3     34984       1945     3450      student          78
# 8              19     35000       1949    12330       barmen          78
# 9               9     34990       1953    16770      manager          78
# 10              8     34989       1958    14550           hr          78
# 11              6     34987       1967    10110      manager          78
# 12             15     34987       1967    30090      manager          78
# 13             24     34989       1958    27870           hr          78
# 14             27     35008       1967    41930          bdm          78
# 15             28     35008       1967    46370          bdm          78
# 16             29     35008       1967    50810          bdm          78
# 17              5     34986       1978     7890           hr          78
# 18             17     34998       1978     7890      student          78
# 19             10     34991       1988    18990          bdm          78
# 20             30     34991       1988    55250          bdm          78
# 21             18     34999       1988    10110      student          78
# 22             23     34988       1999    25650      manager          78
# 23             14     34995       1999    27870  hairdresser          78
# 24             26     35007       1999    37490      student          78
# 25              1     34982       2013    12900      student          78
# 26              2     34983       1967     1230       barmen          78
# 27             13     34994       1967    25650       driver          78
# 28             22     34987       1967    18990      manager          78
# 29              7     34988       1999    12330      manager          78
#
#       Risk
# 0      low
# 1     high
# 2     high
# 3      low
# 4      low
# 5   medium
# 6   medium
# 7   medium
# 8     high
# 9   medium
# 10    high
# 11  medium
# 12     low
# 13  medium
# 14     low
# 15    high
# 16  medium
# 17    high
# 18  medium
# 19     low
# 20    high
# 21     low
# 22     low
# 23     low
# 24  medium
# 25     low
# 26    high
# 27  medium
# 28    high
# 29  medium

# %%
stats = df.describe().transpose()
stats['IQR'] = stats['75%'] - stats['25%']
stats
# Out:
#                count           mean            std      min       25%  \
# TransactionID   30.0      15.500000       8.803408      1.0      8.25
# ClientID        30.0   34993.833333       8.132876  34982.0  34987.25
# BirthYear       30.0    1965.433333      24.426785   1923.0   1946.00
# Amount          30.0  101009.666667  434261.568869   1230.0  12330.00
# Department      30.0      78.000000       0.000000     78.0     78.00
#
#                    50%       75%        max      IQR
# TransactionID     15.5     22.75       30.0     14.5
# ClientID       34991.5  34999.75    35008.0     12.5
# BirthYear       1967.0   1985.50     2013.0     39.5
# Amount         18990.0  29535.00  2399090.0  17205.0
# Department        78.0     78.00       78.0      0.0

# %%
outliers = pd.DataFrame(columns=df.columns)

for col in stats.index:
    iqr = stats.at[col,'IQR']
    cutoff = iqr * 1.5
    lower = stats.at[col,'25%'] - cutoff
    upper = stats.at[col,'75%'] + cutoff
    results = df[(df[col] < lower) | 
                   (df[col] > upper)].copy()
    results['Outlier'] = col
    outliers = outliers.append(results)
# Out:
# C:\Users\monkeyluffy14\AppData\Local\Temp\ipykernel_27208\1561756670.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   outliers = outliers.append(results)
# C:\Users\monkeyluffy14\AppData\Local\Temp\ipykernel_27208\1561756670.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   outliers = outliers.append(results)
# C:\Users\monkeyluffy14\AppData\Local\Temp\ipykernel_27208\1561756670.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   outliers = outliers.append(results)
# C:\Users\monkeyluffy14\AppData\Local\Temp\ipykernel_27208\1561756670.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   outliers = outliers.append(results)
# C:\Users\monkeyluffy14\AppData\Local\Temp\ipykernel_27208\1561756670.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   outliers = outliers.append(results)

# %%
outliers
# Out:
#   TransactionID ClientID BirthYear   Amount Profession Department  Risk  \
# 1            16    34997      1923  2399090  developer         78  high
#
#   Outlier
# 1  Amount

# %%
df
# Out:
#     TransactionID  ClientID  BirthYear   Amount   Profession  Department  \
# 0               4     34985       1923     5670      manager          78
# 1              16     34997       1923  2399090    developer          78
# 2              25     35006       1923    33050           hr          78
# 3              12     34993       1939    23430    professor          78
# 4              21     35002       1939    16770      manager          78
# 5              11     34992       1944    21210   researcher          78
# 6              20     35001       1944    14550      student          78
# 7               3     34984       1945     3450      student          78
# 8              19     35000       1949    12330       barmen          78
# 9               9     34990       1953    16770      manager          78
# 10              8     34989       1958    14550           hr          78
# 11              6     34987       1967    10110      manager          78
# 12             15     34987       1967    30090      manager          78
# 13             24     34989       1958    27870           hr          78
# 14             27     35008       1967    41930          bdm          78
# 15             28     35008       1967    46370          bdm          78
# 16             29     35008       1967    50810          bdm          78
# 17              5     34986       1978     7890           hr          78
# 18             17     34998       1978     7890      student          78
# 19             10     34991       1988    18990          bdm          78
# 20             30     34991       1988    55250          bdm          78
# 21             18     34999       1988    10110      student          78
# 22             23     34988       1999    25650      manager          78
# 23             14     34995       1999    27870  hairdresser          78
# 24             26     35007       1999    37490      student          78
# 25              1     34982       2013    12900      student          78
# 26              2     34983       1967     1230       barmen          78
# 27             13     34994       1967    25650       driver          78
# 28             22     34987       1967    18990      manager          78
# 29              7     34988       1999    12330      manager          78
#
#       Risk
# 0      low
# 1     high
# 2     high
# 3      low
# 4      low
# 5   medium
# 6   medium
# 7   medium
# 8     high
# 9   medium
# 10    high
# 11  medium
# 12     low
# 13  medium
# 14     low
# 15    high
# 16  medium
# 17    high
# 18  medium
# 19     low
# 20    high
# 21     low
# 22     low
# 23     low
# 24  medium
# 25     low
# 26    high
# 27  medium
# 28    high
# 29  medium

# %%
#removing outliers
df.drop(labels=1, axis=0,inplace=True)

# %%
df
# Out:
#     TransactionID  ClientID  BirthYear  Amount   Profession  Department  \
# 0               4     34985       1923    5670      manager          78
# 2              25     35006       1923   33050           hr          78
# 3              12     34993       1939   23430    professor          78
# 4              21     35002       1939   16770      manager          78
# 5              11     34992       1944   21210   researcher          78
# 6              20     35001       1944   14550      student          78
# 7               3     34984       1945    3450      student          78
# 8              19     35000       1949   12330       barmen          78
# 9               9     34990       1953   16770      manager          78
# 10              8     34989       1958   14550           hr          78
# 11              6     34987       1967   10110      manager          78
# 12             15     34987       1967   30090      manager          78
# 13             24     34989       1958   27870           hr          78
# 14             27     35008       1967   41930          bdm          78
# 15             28     35008       1967   46370          bdm          78
# 16             29     35008       1967   50810          bdm          78
# 17              5     34986       1978    7890           hr          78
# 18             17     34998       1978    7890      student          78
# 19             10     34991       1988   18990          bdm          78
# 20             30     34991       1988   55250          bdm          78
# 21             18     34999       1988   10110      student          78
# 22             23     34988       1999   25650      manager          78
# 23             14     34995       1999   27870  hairdresser          78
# 24             26     35007       1999   37490      student          78
# 25              1     34982       2013   12900      student          78
# 26              2     34983       1967    1230       barmen          78
# 27             13     34994       1967   25650       driver          78
# 28             22     34987       1967   18990      manager          78
# 29              7     34988       1999   12330      manager          78
#
#       Risk
# 0      low
# 2     high
# 3      low
# 4      low
# 5   medium
# 6   medium
# 7   medium
# 8     high
# 9   medium
# 10    high
# 11  medium
# 12     low
# 13  medium
# 14     low
# 15    high
# 16  medium
# 17    high
# 18  medium
# 19     low
# 20    high
# 21     low
# 22     low
# 23     low
# 24  medium
# 25     low
# 26    high
# 27  medium
# 28    high
# 29  medium

# %% [markdown]
# ### ENCODING

# %%
df = pd.get_dummies(df, columns=["Profession"])
scale_mapper = {"low":1, "medium":2, "high":3}
df["Risk"] = df["Risk"].replace(scale_mapper)

# %%
df
# Out:
#     TransactionID  ClientID  BirthYear  Amount  Department  Risk  \
# 0               4     34985       1923    5670          78     1
# 2              25     35006       1923   33050          78     3
# 3              12     34993       1939   23430          78     1
# 4              21     35002       1939   16770          78     1
# 5              11     34992       1944   21210          78     2
# 6              20     35001       1944   14550          78     2
# 7               3     34984       1945    3450          78     2
# 8              19     35000       1949   12330          78     3
# 9               9     34990       1953   16770          78     2
# 10              8     34989       1958   14550          78     3
# 11              6     34987       1967   10110          78     2
# 12             15     34987       1967   30090          78     1
# 13             24     34989       1958   27870          78     2
# 14             27     35008       1967   41930          78     1
# 15             28     35008       1967   46370          78     3
# 16             29     35008       1967   50810          78     2
# 17              5     34986       1978    7890          78     3
# 18             17     34998       1978    7890          78     2
# 19             10     34991       1988   18990          78     1
# 20             30     34991       1988   55250          78     3
# 21             18     34999       1988   10110          78     1
# 22             23     34988       1999   25650          78     1
# 23             14     34995       1999   27870          78     1
# 24             26     35007       1999   37490          78     2
# 25              1     34982       2013   12900          78     1
# 26              2     34983       1967    1230          78     3
# 27             13     34994       1967   25650          78     2
# 28             22     34987       1967   18990          78     3
# 29              7     34988       1999   12330          78     2
#
#     Profession_barmen  Profession_bdm  Profession_driver  \
# 0                   0               0                  0
# 2                   0               0                  0
# 3                   0               0                  0
# 4                   0               0                  0
# 5                   0               0                  0
# 6                   0               0                  0
# 7                   0               0                  0
# 8                   1               0                  0
# 9                   0               0                  0
# 10                  0               0                  0
# 11                  0               0                  0
# 12                  0               0                  0
# 13                  0               0                  0
# 14                  0               1                  0
# 15                  0               1                  0
# 16                  0               1                  0
# 17                  0               0                  0
# 18                  0               0                  0
# 19                  0               1                  0
# 20                  0               1                  0
# 21                  0               0                  0
# 22                  0               0                  0
# 23                  0               0                  0
# 24                  0               0                  0
# 25                  0               0                  0
# 26                  1               0                  0
# 27                  0               0                  1
# 28                  0               0                  0
# 29                  0               0                  0
#
#     Profession_hairdresser  Profession_hr  Profession_manager  \
# 0                        0              0                   1
# 2                        0              1                   0
# 3                        0              0                   0
# 4                        0              0                   1
# 5                        0              0                   0
# 6                        0              0                   0
# 7                        0              0                   0
# 8                        0              0                   0
# 9                        0              0                   1
# 10                       0              1                   0
# 11                       0              0                   1
# 12                       0              0                   1
# 13                       0              1                   0
# 14                       0              0                   0
# 15                       0              0                   0
# 16                       0              0                   0
# 17                       0              1                   0
# 18                       0              0                   0
# 19                       0              0                   0
# 20                       0              0                   0
# 21                       0              0                   0
# 22                       0              0                   1
# 23                       1              0                   0
# 24                       0              0                   0
# 25                       0              0                   0
# 26                       0              0                   0
# 27                       0              0                   0
# 28                       0              0                   1
# 29                       0              0                   1
#
#     Profession_professor  Profession_researcher  Profession_student
# 0                      0                      0                   0
# 2                      0                      0                   0
# 3                      1                      0                   0
# 4                      0                      0                   0
# 5                      0                      1                   0
# 6                      0                      0                   1
# 7                      0                      0                   1
# 8                      0                      0                   0
# 9                      0                      0                   0
# 10                     0                      0                   0
# 11                     0                      0                   0
# 12                     0                      0                   0
# 13                     0                      0                   0
# 14                     0                      0                   0
# 15                     0                      0                   0
# 16                     0                      0                   0
# 17                     0                      0                   0
# 18                     0                      0                   1
# 19                     0                      0                   0
# 20                     0                      0                   0
# 21                     0                      0                   1
# 22                     0                      0                   0
# 23                     0                      0                   0
# 24                     0                      0                   1
# 25                     0                      0                   1
# 26                     0                      0                   0
# 27                     0                      0                   0
# 28                     0                      0                   0
# 29                     0                      0                   0

# %%
df.to_csv('cleaned_dataset.csv', index=False)
