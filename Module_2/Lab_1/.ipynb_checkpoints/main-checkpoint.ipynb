# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1 with SUBPLOT
fig = plt.figure(figsize=(9,3))
plt.subplot(1,2,1)
plt.plot(x,y,color='r',label='y function')
plt.subplot(1,2,2)
plt.plot(x,z,color='g',label='z function') #plot etc

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
# Method 2 with SUBPLOTS (with an S)
# create first figure and ax
fig, (ax1, ax2) = plt.subplots(1,2,figsize = (9,3))
# we add a title to the figure or the ax
fig.suptitle('My first SUBPLOTS', fontsize=14)
# we plot the different lines adding them to the axis
ax1.plot(x,y, c='r', label='y = 2x')
ax2.plot(x,z, c='g', label='y = x^2')

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
# Making previous BIGGER
fig, (ax1, ax2) = plt.subplots(1,2,figsize = (12,6))
# we add a title to the figure or the ax
fig.suptitle('My first SUBPLOTS', fontsize=14)
# we plot the different lines adding them to the axis
ax1.plot(x,y, c='r', label='y = 2x')
ax2.plot(x,z, c='g', label='y = x^2')

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
import math

x = np.arange(0,100)
y = x**2
y2 = np.exp(x)

fig, ax = plt.subplots(1,2,figsize = (9,3))

ax[0].plot(x,y, c='r', label='y = x^2')
ax[0].plot(x,y2, c='g', label='y = exp(x)')
ax[0].set_title("Normal Scale")
ax[0].legend()

ax[1].set_xscale("log")
ax[1].set_yscale("log")
ax[1].plot(x,y, c='r', label='y = x^2')
ax[1].plot(x,y2, c='g', label='y = exp(x)')
ax[1].set_title("Logarithmic Scale")
ax[1].legend()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
# added above

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv('fitbit2.csv')
pd.set_option('display.max_columns', 500)
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  MinutesOfSleep  MinutesOfBeingAwake  NumberOfAwakings  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
fig, axes = plt.subplots(1,2,figsize = (12,4))
#fig.suptitle('Median Steps by month VS by work or weekeend', fontsize=14)

# MEDIAN STEPS BY MONTH_ENCODED
# your code here
median_month = fitbit.groupby(['Months_encoded'])['Steps'].median().reset_index()
sns.barplot(x = median_month['Months_encoded'],y = median_month['Steps'],ax=axes[0]).set(xlabel ="Months", ylabel = "Median Steps", title ='Median Steps by Months')
plt.tight_layout()

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
median_work = fitbit.groupby(['Work_or_Weekend'])['Steps'].median().reset_index()
sns.barplot(x = median_work['Work_or_Weekend'],y = median_work['Steps'],ax=axes[1]).set(xlabel ="Work or Weekend", ylabel = "Median Steps", title ='Median Steps by Work or Weekend')
plt.tight_layout()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
fig, axes = plt.subplots(1,3,figsize = (12,4))
x_col = 'Steps'
y_col = ['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary']

for i, y in enumerate(y_col):
    sns.scatterplot(x=fitbit[x_col],y=fitbit[y],ax=axes[i])
    plt.tight_layout()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv("titanic.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes(include='number')
# We can reclassify Survived (binary) and Pclass(rank) to CATEGORICAL variables
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(include='object')
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
plt.style.use('classic')
fig = plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
sns.boxplot(x="Age",data=titanic)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
# second option
sns.distplot(titanic.Age)
# Out:
# C:\Users\monkeyluffy14\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.displot(titanic.Age)

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
for i, j in enumerate(bins):
    print(i,j)
# Out:
# 0 10
# 1 20
# 2 50

# %%
# your code here
fig, axes = plt.subplots(1,3,figsize = (12,4))
bins = [10,20,50]
for i, j in enumerate(bins):
    sns.distplot(titanic.Age, bins=j, ax=axes[i]).set(title="with bins "+str(j))
    plt.tight_layout()
# Out:
# C:\Users\monkeyluffy14\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\monkeyluffy14\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
More bins => more granularity and ability to observe variations but make it overall less visible in my opinion
"""
# Out:
# '\nMore bins => more granularity and ability to observe variations but make it overall less visible in my opinion\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
# Oups, I already did with seaborn. See above

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
titanic['Gender']
# Out:
# 0         male
# 1       female
# 2       female
# 3       female
# 4         male
#          ...
# 1304      male
# 1305    female
# 1306      male
# 1307      male
# 1308      male
# Name: Gender, Length: 1309, dtype: object

# %%
# Method 1 - matplotlib
# your code here
gender = titanic['Gender'].value_counts()
# create figure and axes
plt.bar(gender.index, gender, color=('blue','red'))
# set title
plt.title('Titanic Passengers Gender', fontweight='bold')
plt.ylabel("#Gender")
# Out:
# Text(0, 0.5, '#Gender')

# %%
gender = titanic.groupby(['Gender'])['PassengerId'].count().rename('count').reset_index()
gender
# Out:
#    Gender  count
# 0  female    466
# 1    male    843

# %%
# Method 2 - seaborn
# your code here
sns.barplot(x = gender['Gender'],y = gender['count']).set(title ='Titanic Passengers Gender')
# Out:
# [Text(0.5, 1.0, 'Titanic Passengers Gender')]

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
pclass = titanic.groupby(['Pclass'])['PassengerId'].count().rename('count').reset_index()
sns.barplot(x = pclass['Pclass'],y = pclass['count']).set(title ='Titanic Pclass breakdown')
# Out:
# [Text(0.5, 1.0, 'Titanic Pclass breakdown')]

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
stats = titanic[['Age']].describe().reset_index()
stats.drop(stats.index[0],inplace=True)
stats
# Out:
#   index        Age
# 1  mean  29.879186
# 2   std  13.448335
# 3   min   0.170000
# 4   25%  22.000000
# 5   50%  28.500000
# 6   75%  37.000000
# 7   max  80.000000

# %%
sns.barplot(x = stats['index'],y = stats['Age']).set(title ='Titanic Age statistics')
# Out:
# [Text(0.5, 1.0, 'Titanic Age statistics')]

# %%
"""
Data is quite centered to the mean as noticed previously
Note: Not really at scale to visualize min value (17 months)
"""
# Out:
# '\nNot really at scale to visualize min value (17 months )\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
Data is quite centered to the mean as noticed previously

"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.boxplot(x="Age",data=titanic)
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.scatter(titanic.Age, titanic.Fare)
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Relationship between Fare and Age')
# Out:
# Text(0.5, 1.0, 'Relationship between Fare and Age')

# %%
# Method 2 - seaborn
# your code here
sns.scatterplot(x=titanic.Age,y=titanic.Fare)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
fig=plt.figure(figsize=(8,5))
sns.heatmap(titanic.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
0.37 SIBSP (wtf is that) and Parch
0.26 Survived and Fare
0.22 Parch and Fare
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.boxplot(x="Pclass",y="Age",data=titanic)
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
g = sns.FacetGrid(titanic, col="Gender")
g.map(sns.distplot, "Age")
# Out:
# C:\Users\monkeyluffy14\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\monkeyluffy14\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
